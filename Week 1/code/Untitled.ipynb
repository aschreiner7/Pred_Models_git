# %%
#import packages.
# %matplotlib inline 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
print(os.getcwd())

# %pwd
# Out:
# C:\Users\schre\Documents\GitHub\Pred_Models_git\Week 1\code
# 'C:\\Users\\schre\\Documents\\GitHub\\Pred_Models_git\\Week 1\\code'

# %%
#Import Using Pandas
auto=pd.read_csv("C:\\Users\\schre\\Documents\\GitHub\\Pred_Models_git\\Week 1\\data/AUTO.csv",encoding='latin1') # ../ moves up one in directory
auto.head()
# Out:
#                 Name Drive Type  Mileage (mpg) Fuel Type  Capacity (gal)  \
# 0      Acura Integra      Front           31.0   Regular            13.2
# 1           Acura TL      Front           22.0   Premium            17.1
# 2      Buick Century      Front           22.0   Regular            17.5
# 3      Buick LeSabre      Front           20.0   Regular            17.5
# 4  Buick Park Avenue      Front           21.0   Regular            18.5
#
#    Length (inches)  Wheel Base (inches)  Width (inches)  \
# 0            172.0                101.0            67.0
# 1            193.0                108.0            70.0
# 2            195.0                109.0            73.0
# 3            200.0                112.0            74.0
# 4            207.0                114.0            75.0
#
#    Turning Circle (feet) Weight (lbs)  Door Top (inches)  Luggage (cu. ft.)  \
# 0                   39.0        2,635               47.5               13.0
# ...

# %%
import pandas as pd
data=pd.read_csv("C:\\Users\\akashkumar\\Downloads\\Customers.csv",encoding='latin1')
print(data.head())
